# %% [markdown]
# <a href="https://colab.research.google.com/github/PatchareepornT/bsc_dpdm22/blob/main/%5Bdataset1%5D%20property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
home = pd.read_excel('/content/drive/MyDrive/DPDM65/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน',skiprows=0) #เลือก ชีท บ้าน
home.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %% [markdown]
# #สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %% [markdown]
# #บ้าน

# %% [markdown]
# ###นักประเมินคนที่ 1

# %%
est1 = home[home['ID ผู้ประเมิน']==1]
est1 #100*14
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
est1[est1['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count()
# Out:
# ID ผู้ประเมิน                     100
# post id                           100
# property_type                     100
# ความมั่นใจในการเมินราคาทรัพย์     100
# ราคาทรัพย์                        100
# ประเมินราคาซื้อ-ขาย               100
# ปัจจัยในการประเมินราคาซื้อ-ขาย    100
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    100
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         0
# Unnamed: 13                         1
# dtype: int64

# %%
est1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='1 ขายไม่ได้แน่นอน'].count #มี 1 คน
# Out:
# <bound method DataFrame.count of     ID ผู้ประเมิน                               post id property_type  \
# 90              1  https://nayoo.co/khonkaen/posts/5978    บ้านเดี่ยว
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 90                        มั่นใจ  20949000.0           16000000.0
#
#    ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 90       3,000-30,000 บาท/ตารางวา                        NaN
#
#        ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 90  1 ขายไม่ได้แน่นอน         NaN          NaN          NaN          NaN
#
#     Unnamed: 13
# 90          NaN  >

# %%
est1[est1['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี'].count()
# Out:
# ID ผู้ประเมิน                     54
# post id                           54
# property_type                     54
# ความมั่นใจในการเมินราคาทรัพย์     54
# ราคาทรัพย์                        54
# ประเมินราคาซื้อ-ขาย               54
# ปัจจัยในการประเมินราคาซื้อ-ขาย    54
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    54
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน'].count()
# Out:
# ID ผู้ประเมิน                     43
# post id                           43
# property_type                     43
# ความมั่นใจในการเมินราคาทรัพย์     43
# ราคาทรัพย์                        43
# ประเมินราคาซื้อ-ขาย               43
# ปัจจัยในการประเมินราคาซื้อ-ขาย    43
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    43
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        1
# dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน'].count()
# Out:
# ID ผู้ประเมิน                     2
# post id                           2
# property_type                     2
# ความมั่นใจในการเมินราคาทรัพย์     2
# ราคาทรัพย์                        2
# ประเมินราคาซื้อ-ขาย               2
# ปัจจัยในการประเมินราคาซื้อ-ขาย    2
# เหตุผลไม่มั่นใจราคาประเมิน        0
# ให้คะแนนทรัพย์                    2
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน'].count()
# Out:
# ID ผู้ประเมิน                     0
# post id                           0
# property_type                     0
# ความมั่นใจในการเมินราคาทรัพย์     0
# ราคาทรัพย์                        0
# ประเมินราคาซื้อ-ขาย               0
# ปัจจัยในการประเมินราคาซื้อ-ขาย    0
# เหตุผลไม่มั่นใจราคาประเมิน        0
# ให้คะแนนทรัพย์                    0
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %% [markdown]
# ###นักประเมินคนที่ 2

# %%
est2 = home[home['ID ผู้ประเมิน']==2]
est2 #90*14
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est2[est2['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count()
# Out:
# ID ผู้ประเมิน                     89
# post id                           89
# property_type                     89
# ความมั่นใจในการเมินราคาทรัพย์     89
# ราคาทรัพย์                        89
# ประเมินราคาซื้อ-ขาย               89
# ปัจจัยในการประเมินราคาซื้อ-ขาย    89
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    89
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
est2[est2['ความมั่นใจในการเมินราคาทรัพย์']=='ไม่มั่นใจ'].count()
# Out:
# ID ผู้ประเมิน                     1
# post id                           1
# property_type                     1
# ความมั่นใจในการเมินราคาทรัพย์     1
# ราคาทรัพย์                        1
# ประเมินราคาซื้อ-ขาย               0
# ปัจจัยในการประเมินราคาซื้อ-ขาย    0
# เหตุผลไม่มั่นใจราคาประเมิน        1
# ให้คะแนนทรัพย์                    0
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %%
est2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ล
# ##Map Data

# %% [markdown]
# [ลิงก์ How to Calculate MAPE in Python?](https://www.geeksforgeeks.org/how-to-calculate-mape-in-python/?fbclid=IwAR3nEC-6bUijo9SQocVuPNkkvbkfPawS3VkD3LLyJkAiqOiO52tFpWZMYAQ)

# %%
est2['ประเมิน1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2
# Out:
# <ipython-input-17-5722fc6584f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2['ประเมิน1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# ...

# %%
est2 = est2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
est2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์   ประเมิน2  \
# ...

# %%
table = est2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]

# %%
table = table.dropna(subset=['ราคาทรัพย์']) # row หายไป 29 row เพราะ มีค่า Nan เราไม่ fillna(0) เพราะ เวลาแทนสูตรจะหาไม่ได้

# %%
table
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [90 rows x 4 columns]

# %%
table1 = table['ประเมิน1']

# %%
table2 = table['ประเมิน2']

# %%
table3 = table['ราคาทรัพย์']

# %% [markdown]
# ##Check Data

# %%
table.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2       True
# dtype: bool

# %% [markdown]
# ##NP

# %%
import numpy as np

# %% [markdown]
# ### เรานำเข้า numpy เพื่อทำให้การทำงานของอาร์เรย์ง่ายขึ้น
# - เรากำหนดฟังก์ชัน mape ซึ่งใช้สองอาร์เรย์:
# - y test , pred
# - อาร์เรย์ทั้งสองนี้ถูกแปลงเป็น np
# - MAPE คำนวณโดยใช้สูตรด้านบน

# %% [markdown]
# ##เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# ###def funtion

# %%
def mape(y_test, pred):
    y_test, pred = np.array(y_test), np.array(pred)
    mape = np.mean(np.abs((y_test - pred) / y_test))
    return mape

# %%
mapetable = mape(table1, table2)
mapetable # ค่า mape ของผู้ประเมิน1 กับผู้ประเมิน 2
print(f'ผู้ประเมิน 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetable)
# Out:
# ผู้ประเมิน 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ nan

# %%
mapetable2 = mape(table1, table3)
mapetable2 # ค่า mape ของผู้ประเมิน1 กับ ราคาทรัพย์
print(f'ผู้ประเมิน 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetable2)
# Out:
# ผู้ประเมิน 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.13033922424868483

# %%
mapetable3 = mape(table2, table3)
mapetable3
print(f'ผู้ประเมิน 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetable3)
# Out:
# ผู้ประเมิน 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ nan

# %%
mapetable4 = mape(table2, table1)
mapetable4
print(f'ผู้ประเมิน 2 กับ ผู้ประเมิน 1 มีค่า MAPE อยู่ที่', mapetable4)
# Out:
# ผู้ประเมิน 2 กับ ผู้ประเมิน 1 มีค่า MAPE อยู่ที่ nan

# %%
mapetable5 = mape(table3, table1)
mapetable5
print(f'ราคาทรัพย์ กับ ผู้ประเมิน 1 มีค่า MAPE อยู่ที่', mapetable5)
# Out:
# ราคาทรัพย์ กับ ผู้ประเมิน 1 มีค่า MAPE อยู่ที่ 0.12295717665618242

# %%
mapetable6 = mape(table3, table2)
mapetable6
print(f'ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetable6)
# Out:
# ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ nan

# %% [markdown]
# ##อยากเห็นความสัมพันธ์ ราคามากน้อยกับความมั่นใจ

# %%
est2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
tablehouse = est2[['ราคาทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
tablehouse
# Out:
#      ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1     2700000.0                        มั่นใจ
# 3     2600000.0                        มั่นใจ
# 5     5900000.0                        มั่นใจ
# 7     4400000.0                        มั่นใจ
# 9     2750000.0                        มั่นใจ
# ..          ...                           ...
# 185   5500000.0                        มั่นใจ
# 186   7911000.0                        มั่นใจ
# 187   2000000.0                        มั่นใจ
# 188   4000000.0                        มั่นใจ
# 189   1375000.0                        มั่นใจ
#
# [90 rows x 2 columns]

# %%
tablehouse = tablehouse.dropna(subset=['ราคาทรัพย์'])

# %%
def tran_confirm(x):
  if x == 'มั่นใจ':
    return 1
  if x == 'ไม่มั่นใจ':
    return 0

# %%
tablehouse['Tran_confirm'] = tablehouse['ความมั่นใจในการเมินราคาทรัพย์'].apply(tran_confirm)
tablehouse
# Out:
#      ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  Tran_confirm
# 1     2700000.0                        มั่นใจ             1
# 3     2600000.0                        มั่นใจ             1
# 5     5900000.0                        มั่นใจ             1
# 7     4400000.0                        มั่นใจ             1
# 9     2750000.0                        มั่นใจ             1
# ..          ...                           ...           ...
# 185   5500000.0                        มั่นใจ             1
# 186   7911000.0                        มั่นใจ             1
# 187   2000000.0                        มั่นใจ             1
# 188   4000000.0                        มั่นใจ             1
# 189   1375000.0                        มั่นใจ             1
#
# [90 rows x 3 columns]

# %%
table4 = tablehouse['ราคาทรัพย์']

# %%
table5 = tablehouse['Tran_confirm']

# %%
mapetable7 = mape(table4, table5)
mapetable7
print(f'ราคาทรัพย์ กับ ความมั่นใจในการเมินราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetable7)
# Out:
# ราคาทรัพย์ กับ ความมั่นใจในการเมินราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.9999996522413769

# %% [markdown]
# #ที่ดิน

# %%
land = pd.read_excel('/content/drive/MyDrive/DPDM65/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน',skiprows=0) #เลือก ชีท ที่ดิน
land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
land.describe() #มี210 row 
#ราคาทรัพย์ max 90 ล้าน ถูกสุด 8.5 แสน ราคาทรัพย์เฉลี่ย 11 ล้าน
#ประเมินราคา max 250 ล้าน min 5 แสน เฉลี่ย 10 ล้าน
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count     210.000000  2.100000e+02         2.070000e+02   27.000000
# mean        1.619048  1.670405e+07         1.039831e+07    2.481481
# std         0.723904  4.139794e+07         2.552282e+07    0.509175
# min         1.000000  6.500000e+05         5.000000e+05    2.000000
# 25%         1.000000  2.000000e+06         1.800000e+06    2.000000
# 50%         2.000000  4.000000e+06         3.500000e+06    2.000000
# 75%         2.000000  1.207500e+07         1.000000e+07    3.000000
# max         4.000000  2.860000e+08         2.500000e+08    3.000000
#
#        Unnamed: 11  Unnamed: 12
# count          0.0          1.0
# mean           NaN        100.0
# std            NaN          NaN
# min            NaN        100.0
# 25%            NaN        100.0
# 50%            NaN        100.0
# 75%            NaN        100.0
# max            NaN        100.0

# %%
land[land['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count() # มั่นใจ 207 ไม่มั่นใจ 3
# Out:
# ID ผู้ประเมิน                     207
# post id                           207
# property_type                     207
# ความมั่นใจในการเมินราคาทรัพย์     207
# ราคาทรัพย์                        207
# ประเมินราคาซื้อ-ขาย               207
# ปัจจัยในการประเมินราคาซื้อ-ขาย    207
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    207
# Unnamed: 9                         27
# Unnamed: 10                        27
# Unnamed: 11                         0
# Unnamed: 12                         1
# dtype: int64

# %%
land['ID ผู้ประเมิน'].value_counts() #มี210 row ID[1] = 100 , ID[2] = 100, ID[4] = 10
# Out:
# 1    100
# 2    100
# 4     10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
land1 = land[land['ID ผู้ประเมิน']==1]
land1.head()
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 0               1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3               1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 6               1  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 9               1  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 12              1  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                         มั่นใจ     2800000            1800000.0
# 3                         มั่นใจ    14900000            8000000.0
# 6                         มั่นใจ    90000000           18000000.0
# 9                         มั่นใจ    65000000           35000000.0
# 12                        มั่นใจ     3000000            2200000.0
#
#    ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                    8,000-25,000                        NaN
# ...

# %%
land2 = land[land['ID ผู้ประเมิน']==2]
land2.head()
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 1               2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4               2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7               2  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10              2  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13              2  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                         มั่นใจ     2800000            2000000.0
# 4                         มั่นใจ    14900000           12000000.0
# 7                         มั่นใจ    90000000           70000000.0
# 10                        มั่นใจ    65000000           60000000.0
# 13                        มั่นใจ     3000000            2500000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1     ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# ...

# %%
land4 = land[land['ID ผู้ประเมิน']==4]
land4
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 2               4  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 5               4  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 8               4  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 11              4  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 14              4  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# 17              4  https://nayoo.co/khonkaen/posts/1962        ที่ดิน
# 20              4  https://nayoo.co/khonkaen/posts/2007        ที่ดิน
# 23              4  https://nayoo.co/khonkaen/posts/2040        ที่ดิน
# 26              4  https://nayoo.co/khonkaen/posts/2045        ที่ดิน
# 29              4  https://nayoo.co/khonkaen/posts/2068        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 2                         มั่นใจ     2800000            3000000.0
# ...

# %% [markdown]
# ## Map data

# %%
land2['ประเมิน1'] = land2['post id'].map(land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
land2
# Out:
# <ipython-input-49-f6fe25813445>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land2['ประเมิน1'] = land2['post id'].map(land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# ...

# %%
land2['ประเมิน4'] = land2['post id'].map(land4.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
land2
# Out:
# <ipython-input-50-0552a6523364>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land2['ประเมิน4'] = land2['post id'].map(land4.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# ...

# %%
tableland = land2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tableland
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์    ประเมิน2  \
# ...

# %% [markdown]
# ##Check Data

# %%
tableland.isnull().any()
# Out:
# ID ผู้ประเมิน                     False
# post id                           False
# property_type                     False
# ความมั่นใจในการเมินราคาทรัพย์     False
# ราคาทรัพย์                        False
# ประเมิน2                          False
# ปัจจัยในการประเมินราคาซื้อ-ขาย    False
# เหตุผลไม่มั่นใจราคาประเมิน         True
# ให้คะแนนทรัพย์                    False
# Unnamed: 9                         True
# Unnamed: 10                        True
# Unnamed: 11                        True
# Unnamed: 12                        True
# ประเมิน1                          False
# ประเมิน4                           True
# dtype: bool

# %%
tableland0 = tableland[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2','ประเมิน4']]
tableland0
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0
# ..                                     ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0
#
#        ประเมิน2    ประเมิน4
# 1     2000000.0   3000000.0
# 4    12000000.0   5000000.0
# 7    70000000.0         NaN
# 10   60000000.0  20000000.0
# ...

# %%
tableland0.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# ประเมิน4       True
# dtype: bool

# %%
tableland0.dropna(subset=['ราคาทรัพย์','ประเมิน4']) #ข้อมูล Nan เยอะไป dropna ทำให้ข้อมูลหายหมด
# Out:
#                                  post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1   https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0   2000000.0
# 4   https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0  12000000.0
# 10  https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0  60000000.0
# 16  https://nayoo.co/khonkaen/posts/1962     6000000   4000000.0   5000000.0
# 22  https://nayoo.co/khonkaen/posts/2040     2200000   2500000.0   2500000.0
# 25  https://nayoo.co/khonkaen/posts/2045    12000000   7500000.0  10000000.0
# 28  https://nayoo.co/khonkaen/posts/2068     6700000   5600000.0   6000000.0
#
#       ประเมิน4
# 1    3000000.0
# 4    5000000.0
# 10  20000000.0
# 16   4000000.0
# 22   2500000.0
# 25  10000000.0
# 28   4500000.0

# %%
tableland1 = tableland0['ประเมิน1']
tableland1
# Out:
# 1       1800000.0
# 4       8000000.0
# 7      18000000.0
# 10     35000000.0
# 13      2200000.0
#           ...
# 200     4000000.0
# 202      500000.0
# 204     2000000.0
# 206     1500000.0
# 208     2500000.0
# Name: ประเมิน1, Length: 100, dtype: float64

# %%
tableland2 = tableland0['ประเมิน2']
tableland2
# Out:
# 1       2000000.0
# 4      12000000.0
# 7      70000000.0
# 10     60000000.0
# 13      2500000.0
#           ...
# 200     4000000.0
# 202      750000.0
# 204     2500000.0
# 206     1500000.0
# 208     2800000.0
# Name: ประเมิน2, Length: 100, dtype: float64

# %%
tableland3 = tableland0['ราคาทรัพย์']
tableland3
# Out:
# 1       2800000
# 4      14900000
# 7      90000000
# 10     65000000
# 13      3000000
#          ...
# 200     5000000
# 202      750000
# 204     2650000
# 206     1300000
# 208     3000000
# Name: ราคาทรัพย์, Length: 100, dtype: int64

# %% [markdown]
# ### ทำต่อไม่ได้เพราะข้อมูลน้อยเกินไป หลังจาก Dropna

# %% [markdown]
# #ทาวน์โฮม

# %%
townh = pd.read_excel('/content/drive/MyDrive/DPDM65/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม',skiprows=0) #เลือก ชีท ที่ดิน
townh
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
townh.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# count     240.000000  2.400000e+02         2.400000e+02
# mean        1.500000  1.926117e+06         1.827917e+06
# std         0.501045  8.278491e+05         7.870919e+05
# min         1.000000  5.300000e+05         3.500000e+05
# 25%         1.000000  1.345000e+06         1.300000e+06
# 50%         1.500000  1.750000e+06         1.650000e+06
# 75%         2.000000  2.437500e+06         2.350000e+06
# max         2.000000  4.730000e+06         4.200000e+06
#
#        เหตุผลไม่มั่นใจราคาประเมิน  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# count                         0.0         0.0          0.0          0.0
# mean                          NaN         NaN          NaN          NaN
# std                           NaN         NaN          NaN          NaN
# min                           NaN         NaN          NaN          NaN
# 25%                           NaN         NaN          NaN          NaN
# ...

# %%
townh[townh['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count() #มั่นใจทุกคน
# Out:
# ID ผู้ประเมิน                     240
# post id                           240
# property_type                     240
# ความมั่นใจในการเมินราคาทรัพย์     240
# ราคาทรัพย์                        240
# ประเมินราคาซื้อ-ขาย               240
# ปัจจัยในการประเมินราคาซื้อ-ขาย    240
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    240
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         1
# dtype: int64

# %%
townh['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    120
# 2    120
# Name: ID ผู้ประเมิน, dtype: int64

# %%
townh1 = townh[townh['ID ผู้ประเมิน']==1]
townh1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 6                1    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 8                1    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 125              1  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 126              1  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 127              1  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 128              1  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 129              1  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
townh2 = townh[townh['ID ผู้ประเมิน']==2]
townh2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# ##Map Data

# %%
townh2['ประเมิน1'] = townh2['post id'].map(townh1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
townh2
# Out:
# <ipython-input-65-891188a31380>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townh2['ประเมิน1'] = townh2['post id'].map(townh1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# ...

# %%
townh2 = townh2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
townh2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์   ประเมิน2  \
# ...

# %%
tabletown = townh2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
tabletown
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0  1700000.0  1700000.0
#
# [120 rows x 4 columns]

# %% [markdown]
# ##Check Data

# %%
tabletown.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
tabletown = tabletown.dropna(subset=['ราคาทรัพย์']) #row หายไป 59 row หลัง dropna

# %%
tabletown1 = tabletown['ประเมิน1']

# %%
tabletown2 = tabletown['ประเมิน2']

# %%
tabletown3 = tabletown['ราคาทรัพย์']

# %% [markdown]
# ##เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# ###def function

# %%
mapetown1 = mape(tabletown1, tabletown2)
mapetown1 
print(f'ผู้ประเมิน 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetown1)
# Out:
# ผู้ประเมิน 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.1121168528826893

# %%
mapetown2 = mape(tabletown1, tabletown3)
mapetown2 
print(f'ผู้ประเมิน 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetown2)
# Out:
# ผู้ประเมิน 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.16209125736159383

# %%
mapetown3 = mape(tabletown2, tabletown3)
mapetown3 
print(f'ผู้ประเมิน 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetown3)
# Out:
# ผู้ประเมิน 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.12753580848193072

# %%
mapetown4 = mape(tabletown3, tabletown1)
mapetown4 
print(f'ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetown4)
# Out:
# ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.11373507980201533

# %%
mapetown5 = mape(tabletown3, tabletown2)
mapetown5 
print(f'ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetown5)
# Out:
# ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.08766742521930593

# %% [markdown]
# ##อยากเห็นความสัมพันธ์ ราคามากน้อยกับความมั่นใจ

# %%
townh2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    120
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
tablehome = townh2[['ราคาทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
tablehome
# Out:
#      ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1     1045000.0                        มั่นใจ
# 3      935000.0                        มั่นใจ
# 5     3520000.0                        มั่นใจ
# 7     3850000.0                        มั่นใจ
# 9      990000.0                        มั่นใจ
# ..          ...                           ...
# 235   1430000.0                        มั่นใจ
# 236   1980000.0                        มั่นใจ
# 237   2000000.0                        มั่นใจ
# 238   1790000.0                        มั่นใจ
# 239   1590000.0                        มั่นใจ
#
# [120 rows x 2 columns]

# %%
tablehome = tablehome.dropna(subset=['ราคาทรัพย์'])

# %%
tablehome
# Out:
#      ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1     1045000.0                        มั่นใจ
# 3      935000.0                        มั่นใจ
# 5     3520000.0                        มั่นใจ
# 7     3850000.0                        มั่นใจ
# 9      990000.0                        มั่นใจ
# ..          ...                           ...
# 235   1430000.0                        มั่นใจ
# 236   1980000.0                        มั่นใจ
# 237   2000000.0                        มั่นใจ
# 238   1790000.0                        มั่นใจ
# 239   1590000.0                        มั่นใจ
#
# [120 rows x 2 columns]

# %%
#min = tablehome[tablehome['ราคาทรัพย์'] > 2000000]

# %%
#max = tablehome[tablehome['ราคาทรัพย์'] > 2000000]

# %%
tablehome['Tran_confirm'] = tablehome['ความมั่นใจในการเมินราคาทรัพย์'].apply(tran_confirm)
tablehome
# Out:
#      ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  Tran_confirm
# 1     1045000.0                        มั่นใจ             1
# 3      935000.0                        มั่นใจ             1
# 5     3520000.0                        มั่นใจ             1
# 7     3850000.0                        มั่นใจ             1
# 9      990000.0                        มั่นใจ             1
# ..          ...                           ...           ...
# 235   1430000.0                        มั่นใจ             1
# 236   1980000.0                        มั่นใจ             1
# 237   2000000.0                        มั่นใจ             1
# 238   1790000.0                        มั่นใจ             1
# 239   1590000.0                        มั่นใจ             1
#
# [120 rows x 3 columns]

# %%
tabletown4 = tablehome['ราคาทรัพย์']

# %%
tabletown5 = tablehome['Tran_confirm']

# %%
mapetown6 = mape(tabletown4, tabletown5)
mapetown6
print(f'ราคาทรัพย์ กับ ความมั่นใจในการเมินราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetown6)
# Out:
# ราคาทรัพย์ กับ ความมั่นใจในการเมินราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.9999993679800862

# %% [markdown]
# #อาคารพาณิชย์

# %%
build= pd.read_excel('/content/drive/MyDrive/DPDM65/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์',skiprows=0) #เลือก ชีท อาคารพาณิชย์
build
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
build.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# count      20.000000  2.000000e+01         2.000000e+01
# mean        1.500000  7.710000e+06         6.935000e+06
# std         0.512989  5.768052e+06         4.646818e+06
# min         1.000000  2.400000e+06         2.100000e+06
# 25%         1.000000  3.900000e+06         3.750000e+06
# 50%         1.500000  6.000000e+06         5.500000e+06
# 75%         2.000000  9.000000e+06         8.500000e+06
# max         2.000000  2.250000e+07         2.000000e+07
#
#        เหตุผลไม่มั่นใจราคาประเมิน  Unnamed: 9  Unnamed: 11  Unnamed: 12  \
# count                         0.0   20.000000          0.0          0.0
# mean                          NaN    2.750000          NaN          NaN
# std                           NaN    0.850696          NaN          NaN
# min                           NaN    2.000000          NaN          NaN
# 25%                           NaN    2.000000          NaN          NaN
# ...

# %%
build[build['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count() #มั่นใจทุกคน 20 คน
# Out:
# ID ผู้ประเมิน                     20
# post id                           20
# property_type                     20
# ความมั่นใจในการเมินราคาทรัพย์     20
# ราคาทรัพย์                        20
# ประเมินราคาซื้อ-ขาย               20
# ปัจจัยในการประเมินราคาซื้อ-ขาย    20
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    20
# Unnamed: 9                        20
# Unnamed: 10                       20
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        1
# dtype: int64

# %%
build1 = build[build['ID ผู้ประเมิน']==1]
build1
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 12              1   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 14              1  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 16              1  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 18              1  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
build2 = build[build['ID ผู้ประเมิน']==2]
build2
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 15              2  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 17              2  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 19              2  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# ##Map Data

# %%
build2['ประเมิน1'] = build2['post id'].map(build1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
build2
# Out:
# <ipython-input-93-7b4bae19d817>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   build2['ประเมิน1'] = build2['post id'].map(build1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
tablebuild = build2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tablebuild
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 15              2  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 17              2  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 19              2  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์    ประเมิน2  \
# ...

# %%
tablebuild0 = tablebuild[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
tablebuild0
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0

# %% [markdown]
# ##Check Data

# %%
tablebuild0.isnull().any() #Clean
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
tablebuild1 = tablebuild0['ประเมิน1']

# %%
tablebuild2 = tablebuild0['ประเมิน2']

# %%
tablebuild3 = tablebuild0['ราคาทรัพย์']

# %% [markdown]
# ##เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# ###def function

# %%
mapebuild1 = mape(tablebuild1, tablebuild2)
mapebuild1 
print(f'ผู้ประเมิน 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapebuild1)
# Out:
# ผู้ประเมิน 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.2158208906103643

# %%
mapebuild2 = mape(tablebuild1, tablebuild3)
mapebuild2 
print(f'ผู้ประเมิน 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapebuild2)
# Out:
# ผู้ประเมิน 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.254518341307815

# %%
mapebuild3 = mape(tablebuild2, tablebuild3)
mapebuild3
print(f'ผู้ประเมิน 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapebuild3)
# Out:
# ผู้ประเมิน 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.12428571428571429

# %%
mapebuild4 = mape(tablebuild3, tablebuild1)
mapebuild4
print(f'ราคาทรัพย์ กับ ผู้ประเมิน 1 มีค่า MAPE อยู่ที่', mapebuild4)
# Out:
# ราคาทรัพย์ กับ ผู้ประเมิน 1 มีค่า MAPE อยู่ที่ 0.17643894993894996

# %%
mapebuild5 = mape(tablebuild3, tablebuild2)
mapebuild5
print(f'ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapebuild5)
# Out:
# ราคาทรัพย์ กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.11732295482295482

# %% [markdown]
# ##อยากเห็นความสัมพันธ์ ราคามากน้อยกับความมั่นใจ

# %%
tablebuild['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    10
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
tablebuild00 = tablebuild[['ราคาทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
tablebuild00
# Out:
#     ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1    7000000.0                        มั่นใจ
# 3   12000000.0                        มั่นใจ
# 5   22500000.0                        มั่นใจ
# 7    3500000.0                        มั่นใจ
# 9    3900000.0                        มั่นใจ
# 11   4800000.0                        มั่นใจ
# 13   2400000.0                        มั่นใจ
# 15   5000000.0                        มั่นใจ
# 17   7000000.0                        มั่นใจ
# 19   9000000.0                        มั่นใจ

# %%
tablebuild00['Tran_confirm'] = tablebuild['ความมั่นใจในการเมินราคาทรัพย์'].apply(tran_confirm)
tablebuild00
# Out:
# <ipython-input-107-217efcdff742>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tablebuild00['Tran_confirm'] = tablebuild['ความมั่นใจในการเมินราคาทรัพย์'].apply(tran_confirm)
#     ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  Tran_confirm
# 1    7000000.0                        มั่นใจ             1
# 3   12000000.0                        มั่นใจ             1
# 5   22500000.0                        มั่นใจ             1
# 7    3500000.0                        มั่นใจ             1
# 9    3900000.0                        มั่นใจ             1
# 11   4800000.0                        มั่นใจ             1
# 13   2400000.0                        มั่นใจ             1
# 15   5000000.0                        มั่นใจ             1
# ...

# %%
tablebuild4 = tablebuild00['ราคาทรัพย์']

# %%
tablebuild5 = tablebuild00['Tran_confirm']

# %%
mapebuild6 = mape(tablebuild4, tablebuild5)
mapebuild6
print(f'ราคาทรัพย์ กับ ความมั่นใจในการเมินราคาทรัพย์ มีค่า MAPE อยู่ที่', mapebuild6)
# Out:
# ราคาทรัพย์ กับ ความมั่นใจในการเมินราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.9999998108272283

# %% [markdown]
# เขียน function ตรวจสอบค่าที่เติม 0 ผิด

# %%
max (10,2)
# Out:
# 10

# %%
def check_v(in1,in2) :
    return max (in1/in2,in2/in1)

# %%
check_v(100,12)
# Out:
# 8.333333333333334

# %%
 check_v(100,1200)
# Out:
# 12.0

# %% [markdown]
# ##สร้าง column ใหม่ลงในตาราง home โดย ค่าใน column คือค่าจาก function check (ราคาขาย,ราคาประเมิน)

# %%
table['check1'] = table.apply(lambda x : check_v(x['ราคาทรัพย์'],x['ประเมิน1']),axis=1)
table
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
#        check1
# 1    1.080000
# ...

# %%
check1 = list()
for row in table.iterrows ():
     check1.apply(check_v(row[1]['ราคาทรัพย์'] ,row[1]['ประเมิน1']))
    check1
# Out:
#   File "<tokenize>", line 4
#     check1
#     ^
# IndentationError: unindent does not match any outer indentation level
